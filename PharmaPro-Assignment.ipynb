# %%
##import necessary modules
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
#import excel file
df = pd.read_excel("/Users/apple/Documents/PharmaPro/Study Title.xlsx")
df.head()
# Out:
#                                Public Title of Study  \
# 0  Study of Efficacy and Safety of Two Secukinuma...
# 1              Amroid tablets and ointments in Piles
# 2  It is a study in which the different outside r...
# 3  A study to assess the usefulness of a block te...
# 4  Evaluation of the association between the Ging...
#
#                            Scientific Title of Study  Cause1  Cause1 % Match  \
# 0  A randomized, double-blind, multicenter study ...     NaN             NaN
# 1  Clinical effect of Amroid tablets and Amroid o...     NaN             NaN
# 2  Study Of Extrinsic Risk Factors In Childhood O...     NaN             NaN
# 3  THE EFFECT OF ULTRASOUND GUIDED SPINAE BLOCK O...     NaN             NaN
# 4  Association of the Gingival Line Angle with th...     NaN             NaN
#
#    Cause2  Cause2 % Match  Cause3  Cause3 % Match  Cause4  Cause4 % Match  \
# 0     NaN             NaN     NaN             NaN     NaN             NaN
# ...

# %%
 df.dtypes
# Out:
# Public Title of Study         object
# Scientific Title of Study     object
# Cause1                       float64
# Cause1 % Match               float64
# Cause2                       float64
# Cause2 % Match               float64
# Cause3                       float64
# Cause3 % Match               float64
# Cause4                       float64
# Cause4 % Match               float64
# Unnamed: 10                  float64
# Unnamed: 11                  float64
# Unnamed: 12                  float64
# List of Causes                object
# dtype: object

# %%
##using label enncoder to label target variable
label_encoder =LabelEncoder()

# %%
df["List of Causes"] = label_encoder.fit_transform(df["List of Causes"])

# %%
df.head()
# Out:
#                                Public Title of Study  \
# 0  Study of Efficacy and Safety of Two Secukinuma...
# 1              Amroid tablets and ointments in Piles
# 2  It is a study in which the different outside r...
# 3  A study to assess the usefulness of a block te...
# 4  Evaluation of the association between the Ging...
#
#                            Scientific Title of Study  Cause1  Cause1 % Match  \
# 0  A randomized, double-blind, multicenter study ...     NaN             NaN
# 1  Clinical effect of Amroid tablets and Amroid o...     NaN             NaN
# 2  Study Of Extrinsic Risk Factors In Childhood O...     NaN             NaN
# 3  THE EFFECT OF ULTRASOUND GUIDED SPINAE BLOCK O...     NaN             NaN
# 4  Association of the Gingival Line Angle with th...     NaN             NaN
#
#    Cause2  Cause2 % Match  Cause3  Cause3 % Match  Cause4  Cause4 % Match  \
# 0     NaN             NaN     NaN             NaN     NaN             NaN
# ...

# %%
df.drop(["Unnamed: 10", "Unnamed: 11","Unnamed: 12"], axis = 1, inplace = True)

# %%
df.head()
# Out:
#                                Public Title of Study  \
# 0  Study of Efficacy and Safety of Two Secukinuma...
# 1              Amroid tablets and ointments in Piles
# 2  It is a study in which the different outside r...
# 3  A study to assess the usefulness of a block te...
# 4  Evaluation of the association between the Ging...
#
#                            Scientific Title of Study  Cause1  Cause1 % Match  \
# 0  A randomized, double-blind, multicenter study ...     NaN             NaN
# 1  Clinical effect of Amroid tablets and Amroid o...     NaN             NaN
# 2  Study Of Extrinsic Risk Factors In Childhood O...     NaN             NaN
# 3  THE EFFECT OF ULTRASOUND GUIDED SPINAE BLOCK O...     NaN             NaN
# 4  Association of the Gingival Line Angle with th...     NaN             NaN
#
#    Cause2  Cause2 % Match  Cause3  Cause3 % Match  Cause4  Cause4 % Match  \
# 0     NaN             NaN     NaN             NaN     NaN             NaN
# ...
